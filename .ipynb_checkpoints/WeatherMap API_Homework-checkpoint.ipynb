# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "https://api.openweathermap.org/data/2.5/weather?q="
units = "imperial"


print("Beginning Data Retrieval")
print("-----------------------------")
j=1
city_data = []

for city in cities:
    city_url = (url + city + "&appid=" + api_key + "&units=" + units)
    print(f'Processing record {j} of Set 1 | {city}')
    j=j+1
    try:  
        city_response = requests.get(city_url).json()
        city_data.append({"City Name":city_response['name'], 
                      "Cloudiness": city_response['clouds']['all'], 
                      "Country":city_response['sys']['country'],
                      "Date": city_response['dt'],
                      "Humidity": city_response['main']['humidity'],
                      "Lat": city_response['coord']['lat'],
                      "Lng": city_response['coord']['lon'],
                      "Max Temp": city_response['main']['temp_max'],
                      "Wind Speed": city_response['wind']['speed']})
    except: 
        print ("City not found...")
        pass
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing record 1 of Set 1 | sept-iles
# Processing record 2 of Set 1 | yumen
# Processing record 3 of Set 1 | kemin
# Processing record 4 of Set 1 | georgetown
# Processing record 5 of Set 1 | khatanga
# Processing record 6 of Set 1 | thompson
# Processing record 7 of Set 1 | albany
# Processing record 8 of Set 1 | faanui
# Processing record 9 of Set 1 | mar del plata
# Processing record 10 of Set 1 | sao filipe
# Processing record 11 of Set 1 | mataura
# Processing record 12 of Set 1 | luderitz
# Processing record 13 of Set 1 | dzhusaly
# City not found...
# Processing record 14 of Set 1 | pemberton
# Processing record 15 of Set 1 | phek
# Processing record 16 of Set 1 | tuktoyaktuk
# Processing record 17 of Set 1 | jamestown
# Processing record 18 of Set 1 | egvekinot
# Processing record 19 of Set 1 | ushuaia
# Processing record 20 of Set 1 | dalbandin
# Processing record 21 of Set 1 | geraldton
# Processing record 22 of Set 1 | umzimvubu
# City not found...
# Processing record 23 of Set 1 | mayo
# Processing record 24 of Set 1 | atuona
# Processing record 25 of Set 1 | busselton
# Processing record 26 of Set 1 | kahului
# Processing record 27 of Set 1 | pacific grove
# Processing record 28 of Set 1 | punta arenas
# Processing record 29 of Set 1 | manyana
# Processing record 30 of Set 1 | barrow
# Processing record 31 of Set 1 | chuy
# Processing record 32 of Set 1 | narrabri
# Processing record 33 of Set 1 | miedzychod
# Processing record 34 of Set 1 | puerto ayora
# Processing record 35 of Set 1 | bengkulu
# City not found...
# Processing record 36 of Set 1 | marzuq
# Processing record 37 of Set 1 | aguimes
# Processing record 38 of Set 1 | hilo
# Processing record 39 of Set 1 | rikitea
# Processing record 40 of Set 1 | airai
# Processing record 41 of Set 1 | santa isabel do rio negro
# Processing record 42 of Set 1 | cap malheureux
# Processing record 43 of Set 1 | cape town
# Processing record 44 of Set 1 | mrirt
# City not found...
# Processing record 45 of Set 1 | illoqqortoormiut
# City not found...
# Processing record 46 of Set 1 | portland
# Processing record 47 of Set 1 | skala
# Processing record 48 of Set 1 | ginir
# Processing record 49 of Set 1 | saint-philippe
# Processing record 50 of Set 1 | tarko-sale
# Processing record 51 of Set 1 | turka
# Processing record 52 of Set 1 | new norfolk
# Processing record 53 of Set 1 | paciran
# Processing record 54 of Set 1 | yellowknife
# Processing record 55 of Set 1 | arraial do cabo
# Processing record 56 of Set 1 | nizhneyansk
# City not found...
# Processing record 57 of Set 1 | kodiak
# Processing record 58 of Set 1 | vardo
# Processing record 59 of Set 1 | butaritari
# Processing record 60 of Set 1 | victoria
# Processing record 61 of Set 1 | hermanus
# Processing record 62 of Set 1 | saskylakh
# Processing record 63 of Set 1 | salalah
# Processing record 64 of Set 1 | lebu
# Processing record 65 of Set 1 | college
# Processing record 66 of Set 1 | te anau
# Processing record 67 of Set 1 | saint george
# Processing record 68 of Set 1 | dikson
# Processing record 69 of Set 1 | salcininkai
# Processing record 70 of Set 1 | ust-maya
# Processing record 71 of Set 1 | lompoc
# Processing record 72 of Set 1 | barentsburg
# City not found...
# Processing record 73 of Set 1 | progreso
# Processing record 74 of Set 1 | tasiilaq
# Processing record 75 of Set 1 | niihama
# Processing record 76 of Set 1 | luancheng
# Processing record 77 of Set 1 | san patricio
# Processing record 78 of Set 1 | barawe
# City not found...
# Processing record 79 of Set 1 | inyonga
# Processing record 80 of Set 1 | pizarro
# Processing record 81 of Set 1 | ciudad guayana
# Processing record 82 of Set 1 | severo-kurilsk
# Processing record 83 of Set 1 | vaini
# Processing record 84 of Set 1 | mehamn
# Processing record 85 of Set 1 | pavlohrad
# Processing record 86 of Set 1 | coria
# Processing record 87 of Set 1 | talnakh
# Processing record 88 of Set 1 | adrar
# Processing record 89 of Set 1 | phalombe
# Processing record 90 of Set 1 | ribeira grande
# Processing record 91 of Set 1 | hobart
# Processing record 92 of Set 1 | carnarvon
# Processing record 93 of Set 1 | port elizabeth
# Processing record 94 of Set 1 | daru
# Processing record 95 of Set 1 | port alfred
# Processing record 96 of Set 1 | palabuhanratu
# City not found...
# Processing record 97 of Set 1 | belushya guba
# City not found...
# Processing record 98 of Set 1 | bluff
# Processing record 99 of Set 1 | phan rang
# City not found...
# Processing record 100 of Set 1 | faaa
# Processing record 101 of Set 1 | cabo san lucas
# Processing record 102 of Set 1 | matir
# City not found...
# Processing record 103 of Set 1 | gura calitei
# Processing record 104 of Set 1 | bonavista
# Processing record 105 of Set 1 | bredasdorp
# Processing record 106 of Set 1 | norman wells
# Processing record 107 of Set 1 | kruisfontein
# Processing record 108 of Set 1 | paamiut
# Processing record 109 of Set 1 | avarua
# Processing record 110 of Set 1 | kapaa
# Processing record 111 of Set 1 | yining
# Processing record 112 of Set 1 | chokurdakh
# Processing record 113 of Set 1 | salto
# Processing record 114 of Set 1 | brae
# Processing record 115 of Set 1 | taolanaro
# City not found...
# Processing record 116 of Set 1 | san rafael del sur
# Processing record 117 of Set 1 | tautira
# Processing record 118 of Set 1 | hervey bay
# Processing record 119 of Set 1 | romilly-sur-seine
# Processing record 120 of Set 1 | morbach
# Processing record 121 of Set 1 | ondo
# Processing record 122 of Set 1 | kieta
# Processing record 123 of Set 1 | yaan
# Processing record 124 of Set 1 | fortuna
# Processing record 125 of Set 1 | nabire
# Processing record 126 of Set 1 | isoka
# Processing record 127 of Set 1 | ponta do sol
# Processing record 128 of Set 1 | sayyan
# Processing record 129 of Set 1 | nouadhibou
# Processing record 130 of Set 1 | bac lieu
# City not found...
# Processing record 131 of Set 1 | samarai
# Processing record 132 of Set 1 | hithadhoo
# Processing record 133 of Set 1 | ikalamavony
# Processing record 134 of Set 1 | oktyabrskiy
# Processing record 135 of Set 1 | attawapiskat
# City not found...
# Processing record 136 of Set 1 | souillac
# Processing record 137 of Set 1 | half moon bay
# Processing record 138 of Set 1 | winnipeg
# Processing record 139 of Set 1 | jiazi
# Processing record 140 of Set 1 | kawalu
# Processing record 141 of Set 1 | matagami
# Processing record 142 of Set 1 | kaitangata
# Processing record 143 of Set 1 | babanusah
# City not found...
# Processing record 144 of Set 1 | tagusao
# Processing record 145 of Set 1 | otjiwarongo
# Processing record 146 of Set 1 | amga
# Processing record 147 of Set 1 | sisimiut
# Processing record 148 of Set 1 | ust-kuyga
# Processing record 149 of Set 1 | kumba
# Processing record 150 of Set 1 | gat
# Processing record 151 of Set 1 | lebedinyy
# Processing record 152 of Set 1 | komsomolskiy
# Processing record 153 of Set 1 | codrington
# Processing record 154 of Set 1 | bambous virieux
# Processing record 155 of Set 1 | waipawa
# Processing record 156 of Set 1 | lavrentiya
# Processing record 157 of Set 1 | sitka
# Processing record 158 of Set 1 | mahebourg
# Processing record 159 of Set 1 | shimoda
# Processing record 160 of Set 1 | petropavlovsk-kamchatskiy
# Processing record 161 of Set 1 | clyde river
# Processing record 162 of Set 1 | lugo
# Processing record 163 of Set 1 | solnechnyy
# Processing record 164 of Set 1 | port lincoln
# Processing record 165 of Set 1 | guerrero negro
# Processing record 166 of Set 1 | flinders
# Processing record 167 of Set 1 | micheweni
# Processing record 168 of Set 1 | katsuura
# Processing record 169 of Set 1 | tecoanapa
# Processing record 170 of Set 1 | meulaboh
# Processing record 171 of Set 1 | bathsheba
# Processing record 172 of Set 1 | luena
# Processing record 173 of Set 1 | narsaq
# Processing record 174 of Set 1 | falealupo
# City not found...
# Processing record 175 of Set 1 | martapura
# Processing record 176 of Set 1 | nisia floresta
# Processing record 177 of Set 1 | kavieng
# Processing record 178 of Set 1 | lolua
# City not found...
# Processing record 179 of Set 1 | mareeba
# Processing record 180 of Set 1 | myitkyina
# Processing record 181 of Set 1 | soe
# Processing record 182 of Set 1 | qaanaaq
# Processing record 183 of Set 1 | mys shmidta
# City not found...
# Processing record 184 of Set 1 | miles city
# Processing record 185 of Set 1 | sosnovo-ozerskoye
# Processing record 186 of Set 1 | westport
# Processing record 187 of Set 1 | caceres
# Processing record 188 of Set 1 | miri
# Processing record 189 of Set 1 | punta alta
# Processing record 190 of Set 1 | leningradskiy
# Processing record 191 of Set 1 | riosucio
# Processing record 192 of Set 1 | alyangula
# Processing record 193 of Set 1 | bilibino
# Processing record 194 of Set 1 | nago
# Processing record 195 of Set 1 | east london
# Processing record 196 of Set 1 | hamadan
# City not found...
# Processing record 197 of Set 1 | dunedin
# Processing record 198 of Set 1 | pamplona
# Processing record 199 of Set 1 | foumban
# Processing record 200 of Set 1 | riyadh
# Processing record 201 of Set 1 | mamlyutka
# Processing record 202 of Set 1 | bouar
# Processing record 203 of Set 1 | tuatapere
# Processing record 204 of Set 1 | erenhot
# Processing record 205 of Set 1 | camacha
# Processing record 206 of Set 1 | saint-francois
# Processing record 207 of Set 1 | hasaki
# Processing record 208 of Set 1 | asau
# City not found...
# Processing record 209 of Set 1 | grand gaube
# Processing record 210 of Set 1 | kampong thum
# Processing record 211 of Set 1 | kutum
# Processing record 212 of Set 1 | tak
# Processing record 213 of Set 1 | vostok
# Processing record 214 of Set 1 | itarema
# Processing record 215 of Set 1 | hobyo
# Processing record 216 of Set 1 | provideniya
# Processing record 217 of Set 1 | kloulklubed
# Processing record 218 of Set 1 | cap-aux-meules
# Processing record 219 of Set 1 | mecca
# Processing record 220 of Set 1 | waingapu
# Processing record 221 of Set 1 | kirkenes
# Processing record 222 of Set 1 | paradwip
# City not found...
# Processing record 223 of Set 1 | bontang
# Processing record 224 of Set 1 | castro
# Processing record 225 of Set 1 | porto seguro
# Processing record 226 of Set 1 | palmer
# Processing record 227 of Set 1 | sao felix do xingu
# Processing record 228 of Set 1 | esperance
# Processing record 229 of Set 1 | mackay
# Processing record 230 of Set 1 | usinsk
# Processing record 231 of Set 1 | pampa
# Processing record 232 of Set 1 | dwarka
# Processing record 233 of Set 1 | capitan bado
# Processing record 234 of Set 1 | eureka
# Processing record 235 of Set 1 | bina-etawa
# City not found...
# Processing record 236 of Set 1 | dolbeau
# City not found...
# Processing record 237 of Set 1 | deputatskiy
# Processing record 238 of Set 1 | mount gambier
# Processing record 239 of Set 1 | chicama
# Processing record 240 of Set 1 | kungurtug
# Processing record 241 of Set 1 | klaksvik
# Processing record 242 of Set 1 | yerbogachen
# Processing record 243 of Set 1 | parana
# Processing record 244 of Set 1 | scottsburgh
# City not found...
# Processing record 245 of Set 1 | pergamino
# Processing record 246 of Set 1 | sentyabrskiy
# City not found...
# Processing record 247 of Set 1 | iqaluit
# Processing record 248 of Set 1 | alofi
# Processing record 249 of Set 1 | hereford
# Processing record 250 of Set 1 | carambei
# Processing record 251 of Set 1 | nanortalik
# Processing record 252 of Set 1 | port hardy
# Processing record 253 of Set 1 | pangoa
# Processing record 254 of Set 1 | mana
# Processing record 255 of Set 1 | tiksi
# Processing record 256 of Set 1 | grand river south east
# City not found...
# Processing record 257 of Set 1 | sur
# Processing record 258 of Set 1 | yuksekova
# Processing record 259 of Set 1 | arys
# Processing record 260 of Set 1 | manokwari
# Processing record 261 of Set 1 | taoudenni
# Processing record 262 of Set 1 | linhares
# Processing record 263 of Set 1 | maragogi
# Processing record 264 of Set 1 | caravelas
# Processing record 265 of Set 1 | trincomalee
# Processing record 266 of Set 1 | astoria
# Processing record 267 of Set 1 | jawhar
# Processing record 268 of Set 1 | gandajika
# Processing record 269 of Set 1 | ostrovnoy
# Processing record 270 of Set 1 | kenora
# Processing record 271 of Set 1 | cidreira
# Processing record 272 of Set 1 | lumberton
# Processing record 273 of Set 1 | buala
# Processing record 274 of Set 1 | zhigansk
# Processing record 275 of Set 1 | hofn
# Processing record 276 of Set 1 | padang
# Processing record 277 of Set 1 | grindavik
# Processing record 278 of Set 1 | saleaula
# City not found...
# Processing record 279 of Set 1 | hamilton
# Processing record 280 of Set 1 | tripoli
# Processing record 281 of Set 1 | ilulissat
# Processing record 282 of Set 1 | askiz
# Processing record 283 of Set 1 | port keats
# Processing record 284 of Set 1 | rypin
# Processing record 285 of Set 1 | vila
# Processing record 286 of Set 1 | broken hill
# Processing record 287 of Set 1 | amderma
# City not found...
# Processing record 288 of Set 1 | upernavik
# Processing record 289 of Set 1 | atbasar
# Processing record 290 of Set 1 | sofiysk
# City not found...
# Processing record 291 of Set 1 | jiddah
# City not found...
# Processing record 292 of Set 1 | hualmay
# Processing record 293 of Set 1 | chake chake
# Processing record 294 of Set 1 | phun phin
# City not found...
# Processing record 295 of Set 1 | kargil
# Processing record 296 of Set 1 | alice springs
# Processing record 297 of Set 1 | carutapera
# Processing record 298 of Set 1 | alotau
# City not found...
# Processing record 299 of Set 1 | dingle
# Processing record 300 of Set 1 | namibe
# Processing record 301 of Set 1 | iquique
# Processing record 302 of Set 1 | codajas
# Processing record 303 of Set 1 | nizwa
# Processing record 304 of Set 1 | lahat
# Processing record 305 of Set 1 | zyryanka
# Processing record 306 of Set 1 | sarakhs
# Processing record 307 of Set 1 | san quintin
# Processing record 308 of Set 1 | mocuba
# Processing record 309 of Set 1 | obluche
# City not found...
# Processing record 310 of Set 1 | minab
# Processing record 311 of Set 1 | port blair
# Processing record 312 of Set 1 | karratha
# Processing record 313 of Set 1 | meyungs
# City not found...
# Processing record 314 of Set 1 | tocopilla
# Processing record 315 of Set 1 | nieuw nickerie
# Processing record 316 of Set 1 | mogadishu
# Processing record 317 of Set 1 | oktyabrskoye
# Processing record 318 of Set 1 | camana
# City not found...
# Processing record 319 of Set 1 | svetlogorsk
# Processing record 320 of Set 1 | mokhsogollokh
# Processing record 321 of Set 1 | machinga
# Processing record 322 of Set 1 | kuching
# Processing record 323 of Set 1 | poronaysk
# Processing record 324 of Set 1 | qaqortoq
# Processing record 325 of Set 1 | haibowan
# City not found...
# Processing record 326 of Set 1 | asyut
# Processing record 327 of Set 1 | temba
# Processing record 328 of Set 1 | topeka
# Processing record 329 of Set 1 | paita
# Processing record 330 of Set 1 | lysyye gory
# Processing record 331 of Set 1 | naze
# Processing record 332 of Set 1 | nemuro
# Processing record 333 of Set 1 | chester
# Processing record 334 of Set 1 | waikuku
# Processing record 335 of Set 1 | sandpoint
# Processing record 336 of Set 1 | sola
# Processing record 337 of Set 1 | tumannyy
# City not found...
# Processing record 338 of Set 1 | nhulunbuy
# Processing record 339 of Set 1 | antofagasta
# Processing record 340 of Set 1 | puerto narino
# Processing record 341 of Set 1 | khor
# Processing record 342 of Set 1 | teahupoo
# Processing record 343 of Set 1 | honningsvag
# Processing record 344 of Set 1 | presidente olegario
# Processing record 345 of Set 1 | high level
# Processing record 346 of Set 1 | koslan
# Processing record 347 of Set 1 | nikolskoye
# Processing record 348 of Set 1 | kroya
# Processing record 349 of Set 1 | candawaga
# City not found...
# Processing record 350 of Set 1 | puerto escondido
# Processing record 351 of Set 1 | huanan
# Processing record 352 of Set 1 | maraa
# Processing record 353 of Set 1 | benguela
# Processing record 354 of Set 1 | alekseyevsk
# Processing record 355 of Set 1 | bobo dioulasso
# City not found...
# Processing record 356 of Set 1 | chepareria
# Processing record 357 of Set 1 | chiang khong
# Processing record 358 of Set 1 | sinazongwe
# Processing record 359 of Set 1 | shingu
# Processing record 360 of Set 1 | lorengau
# Processing record 361 of Set 1 | henties bay
# Processing record 362 of Set 1 | ucluelet
# Processing record 363 of Set 1 | thinadhoo
# Processing record 364 of Set 1 | lerwick
# Processing record 365 of Set 1 | broome
# Processing record 366 of Set 1 | estelle
# Processing record 367 of Set 1 | arkansas city
# Processing record 368 of Set 1 | el faiyum
# City not found...
# Processing record 369 of Set 1 | tapaua
# City not found...
# Processing record 370 of Set 1 | koygorodok
# Processing record 371 of Set 1 | aripuana
# Processing record 372 of Set 1 | akyab
# City not found...
# Processing record 373 of Set 1 | beyneu
# Processing record 374 of Set 1 | lagoa
# Processing record 375 of Set 1 | oyama
# Processing record 376 of Set 1 | aras
# Processing record 377 of Set 1 | shelburne
# Processing record 378 of Set 1 | la ronge
# Processing record 379 of Set 1 | aklavik
# Processing record 380 of Set 1 | kununurra
# Processing record 381 of Set 1 | bilma
# Processing record 382 of Set 1 | amudat
# Processing record 383 of Set 1 | lanxi
# Processing record 384 of Set 1 | thai binh
# Processing record 385 of Set 1 | los llanos de aridane
# Processing record 386 of Set 1 | shangqiu
# Processing record 387 of Set 1 | touros
# Processing record 388 of Set 1 | balabac
# Processing record 389 of Set 1 | mut
# Processing record 390 of Set 1 | torbay
# Processing record 391 of Set 1 | obidos
# Processing record 392 of Set 1 | buckeye
# Processing record 393 of Set 1 | pirgos
# Processing record 394 of Set 1 | khonuu
# City not found...
# Processing record 395 of Set 1 | santa helena de goias
# Processing record 396 of Set 1 | ambilobe
# Processing record 397 of Set 1 | diapaga
# Processing record 398 of Set 1 | porto novo
# Processing record 399 of Set 1 | ballina
# Processing record 400 of Set 1 | nevers
# Processing record 401 of Set 1 | kisangani
# Processing record 402 of Set 1 | ordynskoye
# Processing record 403 of Set 1 | chapais
# Processing record 404 of Set 1 | awbari
# Processing record 405 of Set 1 | atar
# Processing record 406 of Set 1 | bafq
# Processing record 407 of Set 1 | gulshat
# City not found...
# Processing record 408 of Set 1 | abiy adi
# City not found...
# Processing record 409 of Set 1 | bethel
# Processing record 410 of Set 1 | smirnykh
# Processing record 411 of Set 1 | gorno-chuyskiy
# City not found...
# Processing record 412 of Set 1 | ogaminana
# Processing record 413 of Set 1 | pemangkat
# City not found...
# Processing record 414 of Set 1 | poya
# Processing record 415 of Set 1 | samalaeulu
# City not found...
# Processing record 416 of Set 1 | siquirres
# Processing record 417 of Set 1 | jardim
# Processing record 418 of Set 1 | viedma
# Processing record 419 of Set 1 | loa janan
# Processing record 420 of Set 1 | baykit
# Processing record 421 of Set 1 | iskateley
# Processing record 422 of Set 1 | lenti
# Processing record 423 of Set 1 | jiwani
# Processing record 424 of Set 1 | samusu
# City not found...
# Processing record 425 of Set 1 | roebourne
# Processing record 426 of Set 1 | sarapul
# Processing record 427 of Set 1 | kombissiri
# Processing record 428 of Set 1 | ngukurr
# City not found...
# Processing record 429 of Set 1 | namatanai
# Processing record 430 of Set 1 | cooma
# Processing record 431 of Set 1 | tabiauea
# City not found...
# Processing record 432 of Set 1 | mulino
# Processing record 433 of Set 1 | kangaatsiaq
# Processing record 434 of Set 1 | husavik
# Processing record 435 of Set 1 | takaka
# Processing record 436 of Set 1 | odweyne
# City not found...
# Processing record 437 of Set 1 | hambantota
# Processing record 438 of Set 1 | warrington
# Processing record 439 of Set 1 | saint-joseph
# Processing record 440 of Set 1 | aberdeen
# Processing record 441 of Set 1 | warqla
# City not found...
# Processing record 442 of Set 1 | pemba
# Processing record 443 of Set 1 | hay river
# Processing record 444 of Set 1 | sakaiminato
# Processing record 445 of Set 1 | kirkwood
# Processing record 446 of Set 1 | vaitupu
# City not found...
# Processing record 447 of Set 1 | tortoli
# Processing record 448 of Set 1 | sinnamary
# Processing record 449 of Set 1 | poum
# Processing record 450 of Set 1 | maturin
# Processing record 451 of Set 1 | havre-saint-pierre
# Processing record 452 of Set 1 | yar-sale
# Processing record 453 of Set 1 | havoysund
# Processing record 454 of Set 1 | richards bay
# Processing record 455 of Set 1 | durant
# Processing record 456 of Set 1 | coahuayana
# Processing record 457 of Set 1 | harper
# Processing record 458 of Set 1 | saint john
# Processing record 459 of Set 1 | ngorongoro
# Processing record 460 of Set 1 | mullaitivu
# City not found...
# Processing record 461 of Set 1 | metu
# Processing record 462 of Set 1 | wenling
# Processing record 463 of Set 1 | nosy varika
# Processing record 464 of Set 1 | bryan
# Processing record 465 of Set 1 | tihuatlan
# Processing record 466 of Set 1 | vila franca do campo
# Processing record 467 of Set 1 | sidney
# Processing record 468 of Set 1 | karla
# Processing record 469 of Set 1 | itoman
# Processing record 470 of Set 1 | jaciara
# Processing record 471 of Set 1 | bom jardim
# Processing record 472 of Set 1 | tsihombe
# City not found...
# Processing record 473 of Set 1 | strelka
# Processing record 474 of Set 1 | olafsvik
# City not found...
# Processing record 475 of Set 1 | xingyi
# Processing record 476 of Set 1 | praia da vitoria
# Processing record 477 of Set 1 | mata
# Processing record 478 of Set 1 | pingshan
# Processing record 479 of Set 1 | ardahan
# Processing record 480 of Set 1 | terrace
# Processing record 481 of Set 1 | the valley
# Processing record 482 of Set 1 | cobija
# Processing record 483 of Set 1 | sao joao da barra
# Processing record 484 of Set 1 | ketchikan
# Processing record 485 of Set 1 | severodvinsk
# Processing record 486 of Set 1 | arman
# Processing record 487 of Set 1 | jiroft
# City not found...
# Processing record 488 of Set 1 | conchal
# Processing record 489 of Set 1 | qandala
# Processing record 490 of Set 1 | vestmannaeyjar
# Processing record 491 of Set 1 | kochki
# Processing record 492 of Set 1 | artyk
# City not found...
# Processing record 493 of Set 1 | porecatu
# Processing record 494 of Set 1 | lulea
# Processing record 495 of Set 1 | longyearbyen
# Processing record 496 of Set 1 | margate
# Processing record 497 of Set 1 | calbuco
# Processing record 498 of Set 1 | hovd
# Processing record 499 of Set 1 | charqueada
# Processing record 500 of Set 1 | abu dhabi
# Processing record 501 of Set 1 | beloha
# Processing record 502 of Set 1 | abu samrah
# Processing record 503 of Set 1 | bandarbeyla
# Processing record 504 of Set 1 | prince rupert
# Processing record 505 of Set 1 | erzin
# Processing record 506 of Set 1 | seminole
# Processing record 507 of Set 1 | pevek
# Processing record 508 of Set 1 | redcar
# Processing record 509 of Set 1 | port-gentil
# Processing record 510 of Set 1 | noumea
# Processing record 511 of Set 1 | svirsk
# Processing record 512 of Set 1 | buariki
# City not found...
# Processing record 513 of Set 1 | karaul
# City not found...
# Processing record 514 of Set 1 | khakhea
# Processing record 515 of Set 1 | sumbawa
# City not found...
# Processing record 516 of Set 1 | bonthe
# Processing record 517 of Set 1 | rawson
# Processing record 518 of Set 1 | elko
# Processing record 519 of Set 1 | ellicott city
# Processing record 520 of Set 1 | lesnoy
# Processing record 521 of Set 1 | labuhan
# Processing record 522 of Set 1 | yerofey pavlovich
# Processing record 523 of Set 1 | anar darreh
# City not found...
# Processing record 524 of Set 1 | kraste
# City not found...
# Processing record 525 of Set 1 | amalapuram
# Processing record 526 of Set 1 | marcona
# City not found...
# Processing record 527 of Set 1 | qostanay
# Processing record 528 of Set 1 | vilhena
# Processing record 529 of Set 1 | elizabethtown
# Processing record 530 of Set 1 | longyan
# Processing record 531 of Set 1 | lyngseidet
# Processing record 532 of Set 1 | yangshe
# Processing record 533 of Set 1 | laguna
# Processing record 534 of Set 1 | baruun-urt
# Processing record 535 of Set 1 | goundam
# Processing record 536 of Set 1 | tomatlan
# Processing record 537 of Set 1 | ronneby
# Processing record 538 of Set 1 | vanavara
# Processing record 539 of Set 1 | mackenzie
# Processing record 540 of Set 1 | pimentel
# Processing record 541 of Set 1 | barillas
# Processing record 542 of Set 1 | chern
# Processing record 543 of Set 1 | nizhniy ufaley
# Processing record 544 of Set 1 | hatillo
# Processing record 545 of Set 1 | campbell river
# Processing record 546 of Set 1 | nishihara
# Processing record 547 of Set 1 | winnemucca
# Processing record 548 of Set 1 | shenzhen
# Processing record 549 of Set 1 | burns lake
# Processing record 550 of Set 1 | road town
# Processing record 551 of Set 1 | kevsala
# Processing record 552 of Set 1 | auki
# Processing record 553 of Set 1 | monchegorsk
# Processing record 554 of Set 1 | xining
# Processing record 555 of Set 1 | khandyga
# Processing record 556 of Set 1 | naugarzan
# City not found...
# Processing record 557 of Set 1 | taltal
# Processing record 558 of Set 1 | san miguel
# Processing record 559 of Set 1 | dubbo
# Processing record 560 of Set 1 | mitu
# Processing record 561 of Set 1 | ancud
# Processing record 562 of Set 1 | areka
# Processing record 563 of Set 1 | kamenskoye
# City not found...
# Processing record 564 of Set 1 | cherskiy
# Processing record 565 of Set 1 | port hawkesbury
# Processing record 566 of Set 1 | zhanaozen
# Processing record 567 of Set 1 | yuzhno-yeniseyskiy
# City not found...
# Processing record 568 of Set 1 | port moresby
# Processing record 569 of Set 1 | san carlos
# Processing record 570 of Set 1 | berlevag
# Processing record 571 of Set 1 | gallup
# Processing record 572 of Set 1 | ciras
# City not found...
# Processing record 573 of Set 1 | igarka
# Processing record 574 of Set 1 | pointe michel
# Processing record 575 of Set 1 | panguna
# Processing record 576 of Set 1 | bagdarin
# Processing record 577 of Set 1 | melton
# Processing record 578 of Set 1 | peniche
# Processing record 579 of Set 1 | amantea
# Processing record 580 of Set 1 | cah ab
# City not found...
# Processing record 581 of Set 1 | ovalle
# Processing record 582 of Set 1 | fatikchhari
# City not found...
# Processing record 583 of Set 1 | umm lajj
# Processing record 584 of Set 1 | novo aripuana
# Processing record 585 of Set 1 | nome
# Processing record 586 of Set 1 | isla vista
# Processing record 587 of Set 1 | salsk
# Processing record 588 of Set 1 | ostrogozhsk
# Processing record 589 of Set 1 | phan thiet
# Processing record 590 of Set 1 | bikaner
# Processing record 591 of Set 1 | marrakesh
# Processing record 592 of Set 1 | zhanatas
# City not found...
# Processing record 593 of Set 1 | yanchukan
# City not found...
# Processing record 594 of Set 1 | staunton
# Processing record 595 of Set 1 | khani
# Processing record 596 of Set 1 | moa
# Processing record 597 of Set 1 | ankazobe
# Processing record 598 of Set 1 | saldanha
# Processing record 599 of Set 1 | knysna
# Processing record 600 of Set 1 | kuryk
# Processing record 601 of Set 1 | escarcega
# Processing record 602 of Set 1 | kattivakkam
# Processing record 603 of Set 1 | rudnichnyy
# Processing record 604 of Set 1 | chegdomyn
# Processing record 605 of Set 1 | brookings
# Processing record 606 of Set 1 | jiayuguan
# Processing record 607 of Set 1 | maceio
# Processing record 608 of Set 1 | wulanhaote
# City not found...
# Processing record 609 of Set 1 | salinas
# Processing record 610 of Set 1 | ornskoldsvik
# Processing record 611 of Set 1 | belaya gora
# Processing record 612 of Set 1 | nelson bay
# Processing record 613 of Set 1 | praya
# Processing record 614 of Set 1 | fukue
# Processing record 615 of Set 1 | blackwater
# Processing record 616 of Set 1 | grand-lahou
# Processing record 617 of Set 1 | batticaloa
# Processing record 618 of Set 1 | zapolyarnyy
# Processing record 619 of Set 1 | san carlos de bariloche

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.to_csv("cities.csv")
city_data_df.head()
# Out:
#     City Name  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0   Sept-Iles          20      CA  1568417171        81  50.20  -66.38
# 1       Yumen          16      CN  1568417241        20  40.29   97.04
# 2       Kemin          46      KG  1568417760        18  42.79   75.70
# 3  Georgetown          20      GY  1568417408        83   6.80  -58.16
# 4    Khatanga          92      RU  1568417223        86  71.98  102.47
#
#    Max Temp  Wind Speed
# 0     48.99        2.75
# 1     53.20        3.27
# 2     49.60        4.56
# 3     80.60        6.93
# 4     30.88        8.34

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], c="mediumblue", edgecolors="black", linewidth=1, alpha = 0.5)
plt.xlabel("Latitude", fontsize=12)
plt.ylabel("Max Temperature (F)", fontsize=12)
plt.title("City Latitude vs. Max Temperature (06/27/19)", fontsize=15)
plt.grid()
plt.savefig("Images/LatVsTemp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], c="mediumblue", edgecolors="black", linewidth=1, alpha = 0.5)
plt.title("City Latitude vs. Humidity (06/27/19)", fontsize=14)
plt.xlabel("Latitude", fontsize=12)
plt.ylabel("Humidity (%)", fontsize=12)
plt.ylim(top=105)
plt.grid()
plt.savefig("Images/LatVsHum.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], c="mediumblue", edgecolors="black", linewidth=1, alpha = 0.5)
plt.title("City Latitude vs. Cloudiness (06/27/19)", fontsize=14)
plt.xlabel("Latitude", fontsize=12)
plt.ylabel("Cloudiness (%)", fontsize=12)
plt.grid()
plt.savefig("Images/LatVsCloud.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], c="mediumblue", edgecolors="black", linewidth=1, alpha = 0.5)
plt.title("City Latitude vs. Wind Speed (06/27/19)", fontsize=14)
plt.xlabel("Latitude", fontsize=12)
plt.ylabel("Wind Speed (mph)", fontsize=12)
plt.grid()
plt.savefig("Images/LatVsWind.png")
plt.show()

# %% [markdown]
# # Analysis
# According to the trends with the provided data via csv file; these are observations listed:
#
# -- Looking at temperature vs latitude, one can see that the higher or lower latitudes will result in cooler temperature; the temperature closer to the equator will result in warmer to hotter temperatures
#
# -- To my observation with the humidity vs. latitude plot, it's evident that there's not much of an absolute relationship to where its extreme. It's volatile and shows no correlation with regions across the latiude and humidity levels. What can you gather from it? that the humidity levels, at the equator, will be predictable from -20 degrees lat. to 20 degress lat.
#
# -- The cloudiness plot doesn't show a direct relationhsip with latitude.
#
# -- Latitude vs. wind speed seems to show a more constant trend across the different latitudes but as far as speed, it shows somewhat of a limit around 20 mph across the latitudes.
